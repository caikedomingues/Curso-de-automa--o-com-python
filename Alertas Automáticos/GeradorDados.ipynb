# %% [markdown]
# link do site do firebase: firebase.google

# %% [markdown]
# bibliotecas necessárias para o exercicio

# %%
import random

import datetime

import time

import requests

# %% [markdown]
# Gerador de dados aleatórios para o banco firebase

# %%
while True:
    
    data = datetime.datetime.now()
    
    vazao = random.randint(100, 200)
    
    logs = f'{{"Data": "{data}", "Vazao": "{vazao}"}}' 
    
    requisicao = requests.post("https://alarme-b3d19-default-rtdb.firebaseio.com/.json", data=logs)
    
    time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       7 logs = f'{{"Data": "{data}", "Vazao": "{vazao}"}}'
#       9 requisicao = requests.post("https://alarme-b3d19-default-rtdb.firebaseio.com/.json", data=logs)
# ---> 11 time.sleep(10)
#
# KeyboardInterrupt:
